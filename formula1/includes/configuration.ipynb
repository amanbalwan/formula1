# %% [markdown]
# # All folder paths for the mounts

# %%
raw_folder_path = '/mnt/formula1adls/raw'
processed_folder_path = '/mnt/formula1adls/processed'
presentation_folder_path = '/mnt/formula1adls/presentation'
