# %% [markdown]
# # Explore DBFS root
# - 1. enable DBFS filstore
# - 2. Upload file in filestore
# - 3. accessing the file in the filestore

# %%
display(dbutils.fs.ls('/'))

# %%
display(dbutils.fs.ls('/FileStore/'))

# %%
display(spark.read.csv('/FileStore/circuits.csv'))
