# %% [markdown]
# # Explore dbutils secrets utility
# - 1. add secret to azure key vault
# - 2. add the secrets to databricks secret scope
# - 3. then use dbutils to access those secrets

# %%
dbutils.secrets.help()

# %%
dbutils.secrets.listScopes()

# %%
dbutils.secrets.list(scope = 'formula1-scope')

# %%
dbutils.secrets.get(scope = 'formula1-scope',key='formula1dl-account-key')
