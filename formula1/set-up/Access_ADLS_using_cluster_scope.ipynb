# %% [markdown]
# # Access ADLS using Cluster scope using Access Key
# - 1. add acess key (key,val) in the cluster config
# - 2. read the from demo container
# - 3. read data from the circuit file

# %%
display(dbutils.fs.ls("abfss://demo@formula1adls.dfs.core.windows.net"))

# %%
display(spark.read.csv("abfss://demo@formula1adls.dfs.core.windows.net/circuits.csv"))
