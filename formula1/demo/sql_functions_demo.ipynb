-- %%
SELECT CURRENT_DATABASE()

-- %%
show DATABASES

-- %%
USE f1_processed

-- %%
SELECT CURRENT_DATABASE()

-- %%
SHOW TABLES

-- %%
SELECT *, CONCAT(driver_ref,'-',code) AS new_driver_ref
FROM f1_processed.drivers

-- %%
SELECT *, SPLIT(name,' ')[0] first_name, SPLIT(name,' ')[1] last_name
FROM f1_processed.drivers

-- %%
SELECT *, current_timestamp
FROM f1_processed.drivers

-- %%
SELECT *, date_format(dob, 'dd-mm-yyyy') as date_of_birth
FROM f1_processed.drivers

-- %%
SELECT *, date_add(dob,1)
FROM f1_processed.drivers

-- %%
SELECT COUNT(*)
FROM drivers

-- %%
SELECT max(dob)
FROM drivers

-- %%
SELECT name 
FROM drivers
WHERE dob = '2000-05-11'

-- %%
SELECT COUNT(*)
FROM drivers
WHERE nationality = 'British'

-- %%
SELECT nationality,COUNT(*)
FROM drivers
GROUP BY nationality
HAVING COUNT(*) > 100
ORDER BY nationality

-- %%
SELECT nationality, name, dob, RANK() OVER(PARTITION BY nationality ORDER BY dob DESC) AS age_rank
FROM drivers
