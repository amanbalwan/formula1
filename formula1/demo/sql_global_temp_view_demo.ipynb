# %% [markdown]
# # Global Temp view
# - 1. Create a Global Temp view on a Dataframe
# - 2. Access the view from SQL cell
# - 3. Access the view from Python cell
# - 4. Access the view from different notebook

# %%
# %run "../includes/configuration"

# %%
race_results = spark.read.parquet(f"{presentation_folder_path}/race_results")

# %%
display(race_results)

# %%
race_results.createOrReplaceGlobalTempView("gv_race_results")

# %%
# %sql
SHOW TABLES IN global_temp

# %%
# %sql
SELECT * 
FROM global_temp.gv_race_results

# %%
spark.sql("SELECT * FROM global_temp.gv_race_results").show()
