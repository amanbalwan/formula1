# %%
# %run "../includes/configuration"

# %%
display(dbutils.fs.ls(processed_folder_path))

# %%
races_df = spark.read.parquet('dbfs:/mnt/formula1adls/processed/races/')

# %%
display(races_df)

# %%
#python style
races_filtered = races_df.filter((races_df["race_year"] == 2019) & (races_df["round"]<=5))

# %%
display(races_filtered)

# %%
#sql style
races_filtered = races_df.where("race_year = 2019 and round <=5")

# %%
display(races_filtered)
