-- %%
SHOW DATABASES

-- %%
SELECT CURRENT_DATABASE()

-- %%
USE f1_processed

-- %%
SELECT CURRENT_DATABASE()

-- %%
SHOW TABLES

-- %%
SELECT *
FROM f1_processed.drivers

-- %%
DESCRIBE TABLE EXTENDED f1_processed.drivers

-- %%
SELECT *
FROM f1_processed.drivers
LIMIT 10;

-- %%
SELECT name, dob AS birthday
FROM f1_processed.drivers
WHERE nationality = 'British' 
AND dob >= '1990-01-01'
ORDER BY birthday DESC

-- %%
SELECT *
FROM drivers
ORDER BY nationality ASC, DOB DESC;

-- %%
SELECT name, dob AS birthday
FROM f1_processed.drivers
WHERE (nationality = 'British' 
AND dob >= '1990-01-01')
OR nationality = 'Indian'
ORDER BY birthday DESC
