# %%
dbutils.notebook.help()

# %%
# !ls

# %%
v_result = dbutils.notebook.run('ingest_circuit_file',0,{'p_data_source': 'Ergast API', 'p_file_date' : '2021-04-18'})

# %%
v_result

# %%
v_result = dbutils.notebook.run('ingest_constructor_file',0,{'p_data_source': 'Ergast API', 'p_file_date' : '2021-04-18'})

# %%
v_result

# %%
v_result = dbutils.notebook.run('ingest_drivers_file',0,{'p_data_source': 'Ergast API', 'p_file_date' : '2021-04-18'})

# %%
v_result

# %%
v_result = dbutils.notebook.run('ingest_lap_times_file',0,{'p_data_source': 'Ergast API', 'p_file_date' : '2021-04-18'})

# %%
v_result

# %%
v_result = dbutils.notebook.run('ingest_pit_stops_file',0,{'p_data_source': 'Ergast API', 'p_file_date' : '2021-04-18'})

# %%
v_result

# %%
v_result = dbutils.notebook.run('ingest_qualifying_file',0,{'p_data_source': 'Ergast API', 'p_file_date' : '2021-04-18'})

# %%
v_result

# %%
v_result = dbutils.notebook.run('ingest_races_file',0,{'p_data_source': 'Ergast API', 'p_file_date' : '2021-04-18'})

# %%
v_result

# %%
v_result = dbutils.notebook.run('ingest_results_file',0,{'p_data_source': 'Ergast API', 'p_file_date' : '2021-04-18'})

# %%
v_result

# %%
# %sql
# SELECT race_id, COUNT(*)
# FROM f1_processed.lap_times
# GROUP BY race_id
# ORDER BY race_id DESC
