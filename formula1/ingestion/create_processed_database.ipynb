-- %%
CREATE DATABASE IF NOT EXISTS f1_processed
LOCATION "dbfs:/mnt/formula1adls/processed/"

-- %%
%python
display(dbutils.fs.ls('dbfs:/mnt/formula1adls/'))

-- %%
DESCRIBE DATABASE EXTENDED f1_processed
